# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import tqdm

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_log_error, mean_squared_error
import re
import datetime

from keras.models import *
from keras.layers import *
from keras.layers.core import Lambda
from keras import backend as K
# Out:
# C:\Users\praveen330\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# C:\Users\praveen330\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\praveen330\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\praveen330\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\praveen330\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\praveen330\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\praveen330\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
### READ DATA AND CREATE FEATURES FOR year, month, day, hour ###
df = pd.read_csv('nyc_taxi.csv')

date = pd.DataFrame(np.vstack(df.timestamp.apply(lambda x: re.sub(r':|-' ,' ', x).split()))[:,:4].astype(int))

df = pd.concat([df, date], axis=1)
df.columns = ['timestamp','value','yr','mt','d','H']
df.head()

print(df.shape)
df.head()
# Out:
# (10320, 6)
#              timestamp  value    yr  mt  d  H
# 0  2014-07-01 00:00:00  10844  2014   7  1  0
# 1  2014-07-01 00:30:00   8127  2014   7  1  0
# 2  2014-07-01 01:00:00   6210  2014   7  1  1
# 3  2014-07-01 01:30:00   4656  2014   7  1  1
# 4  2014-07-01 02:00:00   3820  2014   7  1  2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10320 entries, 0 to 10319
# Data columns (total 6 columns):
# timestamp    10320 non-null object
# value        10320 non-null int64
# yr           10320 non-null int32
# mt           10320 non-null int32
# d            10320 non-null int32
# H            10320 non-null int32
# dtypes: int32(4), int64(1), object(1)
# memory usage: 322.6+ KB

# %%
### PLOT SAMPLE OF DATA ###
#df.iloc[4000:4000+7*48,:].plot(y='value',x='timestamp',figsize=(8,6))
df.iloc[8400:8400+7*48,:].plot(y='value',x='timestamp',figsize=(8,6))
plt.xticks(rotation=70)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300., 350.]),
#  <a list of 8 Text xticklabel objects>)

# %%
### WEEKLY AUTOCORR PLOT (10 WEEKS DEPTH) ###
timeLags = np.arange(1,10*48*7)
autoCorr = [df.value.autocorr(lag=dt) for dt in timeLags]

plt.figure(figsize=(19,8))
plt.plot(1.0/(48*7)*timeLags, autoCorr);
plt.xlabel('time lag [weeks]'); plt.ylabel('correlation coeff', fontsize=12);

# %%
### CREATE WEEKDAY FEATURE AND COMPUTE THE MEAN FOR WEEKDAYS AT EVERY HOURS ###
weekday = df[['yr', 'mt', 'd']].apply(lambda x: datetime.datetime(x['yr'], x['mt'], x['d']).weekday(),axis=1).values
# weekend = weekday.copy()
# weekend[np.logical_and(weekend != 5, weekend != 6)] = 0
# weekend[weekend != 0] = 1

df['weekday'] = weekday
df['weekday_hour'] = df.weekday.astype(str) +' '+ df.H.astype(str)
df['m_weekday'] = df.weekday_hour.replace(df[:5000].groupby('weekday_hour')['value'].mean().to_dict())

# %%
### CREATE GENERATOR FOR LSTM ###
sequence_length = 48

def gen_index(id_df, seq_length, seq_cols):

    data_matrix =  id_df[seq_cols]
    num_elements = data_matrix.shape[0]

    for start, stop in zip(range(0, num_elements-seq_length, 1), range(seq_length, num_elements, 1)):
        
        yield data_matrix[stop-sequence_length:stop].values.reshape((-1,len(seq_cols)))

# %%
### CREATE AND STANDARDIZE DATA FOR LSTM ### 
cnt, mean = [], []
for sequence in gen_index(df, sequence_length, ['value']):
    cnt.append(sequence)
    
for sequence in gen_index(df, sequence_length, ['m_weekday']):
    mean.append(sequence)

cnt, mean = np.log(cnt), np.log(mean)
cnt = cnt - mean
cnt.shape
# Out:
# (10272, 48, 1)

# %%
### CREATE AND STANDARDIZE LABEL FOR LSTM ###
init = df.m_weekday[sequence_length:].apply(np.log).values
label = df.value[sequence_length:].apply(np.log).values - init
label.shape
# Out:
# (10272,)

# %%
### DEFINE QUANTILE LOSS ###
def q_loss(q,y,f):
    e = (y-f)
    return K.mean(K.maximum(q*e, (q-1)*e), axis=-1)

# %%
### TRAIN TEST SPLIT ###
X_train, X_test = cnt[:5000], cnt[5000:]
y_train, y_test = label[:5000], label[5000:]

# %%
### CREATE MODEL ###
losses = [lambda y,f: q_loss(0.1,y,f), lambda y,f: q_loss(0.5,y,f), lambda y,f: q_loss(0.9,y,f)]

inputs = Input(shape=(X_train.shape[1], X_train.shape[2]))
lstm = Bidirectional(LSTM(64, return_sequences=True, dropout=0.3))(inputs, training = True)
lstm = Bidirectional(LSTM(16, return_sequences=False, dropout=0.3))(lstm, training = True)
dense = Dense(50)(lstm)
out10 = Dense(1)(dense)
out50 = Dense(1)(dense)
out90 = Dense(1)(dense)

model = Model(inputs, [out10,out50,out90])

model.compile(loss=losses, optimizer='adam', loss_weights = [0.3,0.3,0.3])
# Out:
# WARNING:tensorflow:From C:\Users\praveen330\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:1192: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From C:\Users\praveen330\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:1299: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
history = model.fit(X_train, [y_train,y_train,y_train], epochs=50, batch_size=128, verbose=2, shuffle=True)
# Out:
# Epoch 1/50
# 35s - loss: 0.0294 - dense_2_loss: 0.0291 - dense_3_loss: 0.0445 - dense_4_loss: 0.0243
# Epoch 2/50
# 25s - loss: 0.0268 - dense_2_loss: 0.0248 - dense_3_loss: 0.0424 - dense_4_loss: 0.0220
# Epoch 3/50
# 25s - loss: 0.0262 - dense_2_loss: 0.0239 - dense_3_loss: 0.0419 - dense_4_loss: 0.0216
# Epoch 4/50
# 29s - loss: 0.0257 - dense_2_loss: 0.0231 - dense_3_loss: 0.0410 - dense_4_loss: 0.0215
# Epoch 5/50
# 31s - loss: 0.0250 - dense_2_loss: 0.0223 - dense_3_loss: 0.0400 - dense_4_loss: 0.0211
# Epoch 6/50
# 25s - loss: 0.0242 - dense_2_loss: 0.0212 - dense_3_loss: 0.0390 - dense_4_loss: 0.0203
# Epoch 7/50
# 24s - loss: 0.0233 - dense_2_loss: 0.0205 - dense_3_loss: 0.0375 - dense_4_loss: 0.0197
# Epoch 8/50
# 25s - loss: 0.0224 - dense_2_loss: 0.0200 - dense_3_loss: 0.0361 - dense_4_loss: 0.0185
# Epoch 9/50
# 24s - loss: 0.0223 - dense_2_loss: 0.0199 - dense_3_loss: 0.0359 - dense_4_loss: 0.0184
# Epoch 10/50
# 25s - loss: 0.0215 - dense_2_loss: 0.0187 - dense_3_loss: 0.0349 - dense_4_loss: 0.0180
# Epoch 11/50
# 26s - loss: 0.0212 - dense_2_loss: 0.0186 - dense_3_loss: 0.0345 - dense_4_loss: 0.0175
# Epoch 12/50
# 25s - loss: 0.0209 - dense_2_loss: 0.0184 - dense_3_loss: 0.0342 - dense_4_loss: 0.0172
# Epoch 13/50
# 25s - loss: 0.0206 - dense_2_loss: 0.0182 - dense_3_loss: 0.0337 - dense_4_loss: 0.0168
# Epoch 14/50
# 25s - loss: 0.0204 - dense_2_loss: 0.0182 - dense_3_loss: 0.0331 - dense_4_loss: 0.0168
# Epoch 15/50
# 27s - loss: 0.0201 - dense_2_loss: 0.0178 - dense_3_loss: 0.0325 - dense_4_loss: 0.0166
# Epoch 16/50
# 29s - loss: 0.0203 - dense_2_loss: 0.0183 - dense_3_loss: 0.0331 - dense_4_loss: 0.0164
# Epoch 17/50
# 27s - loss: 0.0204 - dense_2_loss: 0.0183 - dense_3_loss: 0.0330 - dense_4_loss: 0.0168
# Epoch 18/50
# 26s - loss: 0.0201 - dense_2_loss: 0.0178 - dense_3_loss: 0.0325 - dense_4_loss: 0.0167
# Epoch 19/50
# 26s - loss: 0.0197 - dense_2_loss: 0.0177 - dense_3_loss: 0.0320 - dense_4_loss: 0.0161
# Epoch 20/50
# 27s - loss: 0.0199 - dense_2_loss: 0.0177 - dense_3_loss: 0.0321 - dense_4_loss: 0.0164
# Epoch 21/50
# 25s - loss: 0.0197 - dense_2_loss: 0.0175 - dense_3_loss: 0.0316 - dense_4_loss: 0.0165
# Epoch 22/50
# 25s - loss: 0.0197 - dense_2_loss: 0.0177 - dense_3_loss: 0.0318 - dense_4_loss: 0.0160
# Epoch 23/50
# 24s - loss: 0.0195 - dense_2_loss: 0.0174 - dense_3_loss: 0.0316 - dense_4_loss: 0.0160
# Epoch 24/50
# 25s - loss: 0.0194 - dense_2_loss: 0.0171 - dense_3_loss: 0.0318 - dense_4_loss: 0.0157
# Epoch 25/50
# 24s - loss: 0.0194 - dense_2_loss: 0.0172 - dense_3_loss: 0.0314 - dense_4_loss: 0.0160
# Epoch 26/50
# 26s - loss: 0.0193 - dense_2_loss: 0.0170 - dense_3_loss: 0.0315 - dense_4_loss: 0.0160
# Epoch 27/50
# 32s - loss: 0.0193 - dense_2_loss: 0.0173 - dense_3_loss: 0.0317 - dense_4_loss: 0.0155
# Epoch 28/50
# 27s - loss: 0.0192 - dense_2_loss: 0.0170 - dense_3_loss: 0.0315 - dense_4_loss: 0.0154
# Epoch 29/50
# 26s - loss: 0.0195 - dense_2_loss: 0.0172 - dense_3_loss: 0.0323 - dense_4_loss: 0.0156
# Epoch 30/50
# 26s - loss: 0.0188 - dense_2_loss: 0.0167 - dense_3_loss: 0.0309 - dense_4_loss: 0.0149
# Epoch 31/50
# 26s - loss: 0.0191 - dense_2_loss: 0.0173 - dense_3_loss: 0.0312 - dense_4_loss: 0.0151
# Epoch 32/50
# 25s - loss: 0.0185 - dense_2_loss: 0.0164 - dense_3_loss: 0.0304 - dense_4_loss: 0.0149
# Epoch 33/50
# 26s - loss: 0.0183 - dense_2_loss: 0.0164 - dense_3_loss: 0.0302 - dense_4_loss: 0.0146
# Epoch 34/50
# 25s - loss: 0.0187 - dense_2_loss: 0.0167 - dense_3_loss: 0.0309 - dense_4_loss: 0.0147
# Epoch 35/50
# 31s - loss: 0.0184 - dense_2_loss: 0.0166 - dense_3_loss: 0.0301 - dense_4_loss: 0.0145
# Epoch 36/50
# 29s - loss: 0.0180 - dense_2_loss: 0.0158 - dense_3_loss: 0.0297 - dense_4_loss: 0.0144
# Epoch 37/50
# 30s - loss: 0.0180 - dense_2_loss: 0.0157 - dense_3_loss: 0.0298 - dense_4_loss: 0.0145
# Epoch 38/50
# 30s - loss: 0.0182 - dense_2_loss: 0.0160 - dense_3_loss: 0.0303 - dense_4_loss: 0.0145
# Epoch 39/50
# 28s - loss: 0.0182 - dense_2_loss: 0.0158 - dense_3_loss: 0.0300 - dense_4_loss: 0.0149
# Epoch 40/50
# 28s - loss: 0.0180 - dense_2_loss: 0.0160 - dense_3_loss: 0.0298 - dense_4_loss: 0.0143
# Epoch 41/50
# 25s - loss: 0.0179 - dense_2_loss: 0.0160 - dense_3_loss: 0.0296 - dense_4_loss: 0.0141
# Epoch 42/50
# 26s - loss: 0.0180 - dense_2_loss: 0.0160 - dense_3_loss: 0.0298 - dense_4_loss: 0.0143
# Epoch 43/50
# 25s - loss: 0.0175 - dense_2_loss: 0.0157 - dense_3_loss: 0.0290 - dense_4_loss: 0.0136
# Epoch 44/50
# 26s - loss: 0.0178 - dense_2_loss: 0.0157 - dense_3_loss: 0.0294 - dense_4_loss: 0.0141
# Epoch 45/50
# 26s - loss: 0.0174 - dense_2_loss: 0.0151 - dense_3_loss: 0.0289 - dense_4_loss: 0.0141
# Epoch 46/50
# 25s - loss: 0.0170 - dense_2_loss: 0.0147 - dense_3_loss: 0.0286 - dense_4_loss: 0.0135
# Epoch 47/50
# 26s - loss: 0.0173 - dense_2_loss: 0.0151 - dense_3_loss: 0.0287 - dense_4_loss: 0.0139
# Epoch 48/50
# 27s - loss: 0.0171 - dense_2_loss: 0.0148 - dense_3_loss: 0.0286 - dense_4_loss: 0.0135
# Epoch 49/50
# 32s - loss: 0.0170 - dense_2_loss: 0.0151 - dense_3_loss: 0.0284 - dense_4_loss: 0.0133
# Epoch 50/50
# 38s - loss: 0.0169 - dense_2_loss: 0.0146 - dense_3_loss: 0.0284 - dense_4_loss: 0.0134

# %%
### QUANTILEs BOOTSTRAPPING ###
pred_10, pred_50, pred_90 = [], [], []
NN = K.function([model.layers[0].input, K.learning_phase()], 
                [model.layers[-3].output,model.layers[-2].output,model.layers[-1].output])

for i in tqdm.tqdm(range(0,100)):
    predd = NN([X_test, 0.5])
    pred_10.append(predd[0])
    pred_50.append(predd[1])
    pred_90.append(predd[2])

pred_10 = np.asarray(pred_10)[:,:,0] 
pred_50 = np.asarray(pred_50)[:,:,0]
pred_90 = np.asarray(pred_90)[:,:,0]
# Out:
# 100%|██████████| 100/100 [21:53<00:00, 11.89s/it]

# %%
### REVERSE TRANSFORM PREDICTIONS ###
import numpy as np
pred_90_m = np.exp(np.quantile(pred_90,0.9,axis=0) + init[5000:])
pred_50_m = np.exp(pred_50.mean(axis=0) + init[5000:])
pred_10_m = np.exp(np.quantile(pred_10,0.1,axis=0) + init[5000:])

# %%
### EVALUATION METRIC ###
mean_squared_log_error(np.exp(y_test + init[5000:]), pred_50_m)
# Out:
# 0.056135390059340456

# %%
### PLOT QUANTILE PREDICTIONS ###
plt.figure(figsize=(16,8))
plt.plot(pred_90_m, color='cyan')
plt.plot(pred_50_m, color='blue')
plt.plot(pred_10_m, color='green')

### CROSSOVER CHECK ###
plt.scatter(np.where(np.logical_or(pred_50_m>pred_90_m, pred_50_m<pred_10_m))[0], 
            pred_50_m[np.logical_or(pred_50_m>pred_90_m, pred_50_m<pred_10_m)], c='red', s=50)

# %%
### PLOT UNCERTAINTY INTERVAL LENGHT WITH REAL DATA ###
plt.figure(figsize=(16,8))
plt.plot(np.exp(y_test + init[5000:]), color='red', alpha=0.4)
plt.scatter(range(len(pred_10_m)), pred_90_m - pred_10_m)
